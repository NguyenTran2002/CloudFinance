# %%
import datetime
import random
import pandas as pd

# navigate to the Features folder
import sys
sys.path.append(sys.path[0]+'/../Features') # .. instead of . because we're in the Jupyter Tools folder

# import features
import helper

# %%
# read in the main data
main_df = pd.read_csv('../Data/Test Data/Samples.csv')

main_df.head()
# Out:
#           Unique ID                                        Description  \
# 0  1676269022665425      Randomly generated expenses for Uncategorized
# 1  1676269022684482                Randomly generated expenses for Pet
# 2  1676269022670686  Randomly generated expenses for Health and Fit...
# 3  1676269022639549          Randomly generated expenses for Education
# 4  1676269022635054           Randomly generated expenses for Clothing
#
#              Category  Amount        Date                   Account  \
# 0       Uncategorized     714  2018-12-14  Amex Blue Cash Preferred
# 1                 Pet     519  2021-05-18               Discover It
# 2  Health and Fitness     168  2019-08-23        Chase Freedom Flex
# 3           Education     288  2015-11-16        Chase Freedom Flex
# 4            Clothing     951  2015-05-12               Discover It
#
#   Third Party
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
# sort the main_df by date in descending order
main_df = main_df.sort_values(by = ['Date'], ascending = False)

main_df
# Out:
#            Unique ID                                        Description  \
# 11  1676269022688996     Randomly generated expenses for Transportation
# 14  1676269022687789    Randomly generated expenses for Food and Dining
# 1   1676269022684482                Randomly generated expenses for Pet
# 12  1676269022671634           Randomly generated expenses for Shopping
# 9   1676269022670847               Randomly generated expenses for Home
# 2   1676269022670686  Randomly generated expenses for Health and Fit...
# 7   1676269022666473  Randomly generated expenses for Business Services
# 0   1676269022665425      Randomly generated expenses for Uncategorized
# 5   1676269022661737    Randomly generated expenses for Food and Dining
# 13  1676269022652734    Randomly generated expenses for Food and Dining
# 8   1676269022646494     Randomly generated expenses for Transportation
# 10  1676269022646341           Randomly generated expenses for Shopping
# ...

# %%
# reset the index of main_df
main_df = main_df.reset_index(drop = True)

main_df
# Out:
#            Unique ID                                        Description  \
# 0   1676269022688996     Randomly generated expenses for Transportation
# 1   1676269022687789    Randomly generated expenses for Food and Dining
# 2   1676269022684482                Randomly generated expenses for Pet
# 3   1676269022671634           Randomly generated expenses for Shopping
# 4   1676269022670847               Randomly generated expenses for Home
# 5   1676269022670686  Randomly generated expenses for Health and Fit...
# 6   1676269022666473  Randomly generated expenses for Business Services
# 7   1676269022665425      Randomly generated expenses for Uncategorized
# 8   1676269022661737    Randomly generated expenses for Food and Dining
# 9   1676269022652734    Randomly generated expenses for Food and Dining
# 10  1676269022646494     Randomly generated expenses for Transportation
# 11  1676269022646341           Randomly generated expenses for Shopping
# ...
